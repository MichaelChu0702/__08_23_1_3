# %%
import csv
with open('學生成績.csv',mode='r',encoding='utf-8',newline='') as file:
    csvReader=csv.reader(file)
    #next(csvReader)
    #for row in csvReader:
       # print(row)
    students=list(csvReader)
students
# Out:
# [['姓名', '國文', '英文', '數學', '地理', '歷史'],
#  ['姜琬婷', '50', '89', '79', '96', '53'],
#  ['翁鈺婷', '65', '62', '95', '95', '87'],
#  ['賴心怡', '67', '75', '80', '78', '58'],
#  ['王志謙', '65', '55', '75', '94', '86'],
#  ['黃名明', '85', '80', '79', '96', '72'],
#  ['鄧淑娟', '82', '58', '86', '53', '50'],
#  ['黃志福', '95', '58', '63', '80', '72'],
#  ['昌嘉洋', '52', '95', '90', '86', '68'],
#  ['蔡偉成', '84', '53', '83', '81', '62'],
#  ['林向鈺', '86', '89', '62', '94', '68'],
#  ['林義皓', '90', '69', '94', '60', '97'],
#  ['錢佩豪', '83', '98', '67', '63', '83'],
#  ['楊少亮', '50', '97', '66', '71', '65'],
#  ['郭致恬', '74', '77', '88', '80', '59'],
#  ['陳筱涵', '98', '80', '79', '100', '93'],
#  ['魏秋萍', '50', '56', '80', '59', '51'],
#  ['陳逸華', '95', '86', '77', '57', '56'],
#  ['張天亨', '85', '75', '98', '67', '72'],
#  ['鄧亭聿', '93', '71', '64', '63', '89'],
#  ['藍哲嘉', '94', '63', '50', '62', '64'],
#  ['盧文啟', '77', '97', '50', '85', '66'],
#  ['趙家豪', '79', '53', '74', '67', '80'],
#  ['金宜芳', '53', '85', '91', '60', '81'],
#  ['方雅慧', '76', '91', '74', '78', '61'],
#  ['陳怡容', '100', '99', '64', '88', '78'],
#  ['李進慧', '74', '65', '73', '64', '92'],
#  ['林志喜', '77', '77', '63', '75', '60'],
#  ['謝佳穎', '89', '97', '69', '67', '60'],
#  ['王孝純', '89', '66', '69', '65', '88'],
#  ['林希啟', '60', '84', '54', '62', '67'],
#  ['張彥博', '54', '64', '95', '77', '97'],
#  ['蕭怡伶', '53', '65', '94', '97', '64'],
#  ['陳志偉', '54', '81', '99', '56', '63'],
#  ['李進慧', '79', '70', '80', '81', '54'],
#  ['張伊映', '75', '81', '72', '87', '97'],
#  ['王泓泰', '75', '52', '56', '93', '73'],
#  ['張凡成', '57', '75', '95', '83', '93'],
#  ['梁柏宇', '96', '74', '58', '54', '73'],
#  ['蔡嘉音', '87', '75', '66', '57', '99'],
#  ['蔡至剛', '82', '74', '66', '52', '67'],
#  ['黃雅慧', '71', '87', '67', '53', '65'],
#  ['周芷蓁', '62', '79', '72', '75', '74'],
#  ['蔡至剛', '50', '67', '98', '97', '54'],
#  ['張軒宸', '58', '86', '71', '65', '85'],
#  ['黃淑芬', '83', '70', '91', '56', '58'],
#  ['邱亭君', '98', '94', '62', '91', '98'],
#  ['楊綺芬', '59', '55', '64', '78', '99'],
#  ['馮淑芬', '68', '90', '53', '68', '93'],
#  ['蕭怡伶', '100', '54', '56', '98', '87'],
#  ['林柏洋', '71', '51', '83', '74', '92']]

# %%
import pandas as pd
dataFrame1=pd.DataFrame(students)
dataFrame1.columns=dataFrame1.iloc[0]
dataFrame2=dataFrame1.iloc[1:]#1到最後
dataFrame2
# Out:
# 0    姓名   國文  英文  數學   地理  歷史
# 1   姜琬婷   50  89  79   96  53
# 2   翁鈺婷   65  62  95   95  87
# 3   賴心怡   67  75  80   78  58
# 4   王志謙   65  55  75   94  86
# 5   黃名明   85  80  79   96  72
# 6   鄧淑娟   82  58  86   53  50
# 7   黃志福   95  58  63   80  72
# 8   昌嘉洋   52  95  90   86  68
# 9   蔡偉成   84  53  83   81  62
# 10  林向鈺   86  89  62   94  68
# 11  林義皓   90  69  94   60  97
# 12  錢佩豪   83  98  67   63  83
# 13  楊少亮   50  97  66   71  65
# 14  郭致恬   74  77  88   80  59
# 15  陳筱涵   98  80  79  100  93
# 16  魏秋萍   50  56  80   59  51
# 17  陳逸華   95  86  77   57  56
# 18  張天亨   85  75  98   67  72
# 19  鄧亭聿   93  71  64   63  89
# 20  藍哲嘉   94  63  50   62  64
# 21  盧文啟   77  97  50   85  66
# 22  趙家豪   79  53  74   67  80
# 23  金宜芳   53  85  91   60  81
# 24  方雅慧   76  91  74   78  61
# 25  陳怡容  100  99  64   88  78
# 26  李進慧   74  65  73   64  92
# 27  林志喜   77  77  63   75  60
# 28  謝佳穎   89  97  69   67  60
# 29  王孝純   89  66  69   65  88
# 30  林希啟   60  84  54   62  67
# 31  張彥博   54  64  95   77  97
# 32  蕭怡伶   53  65  94   97  64
# 33  陳志偉   54  81  99   56  63
# 34  李進慧   79  70  80   81  54
# 35  張伊映   75  81  72   87  97
# 36  王泓泰   75  52  56   93  73
# 37  張凡成   57  75  95   83  93
# 38  梁柏宇   96  74  58   54  73
# 39  蔡嘉音   87  75  66   57  99
# 40  蔡至剛   82  74  66   52  67
# 41  黃雅慧   71  87  67   53  65
# 42  周芷蓁   62  79  72   75  74
# 43  蔡至剛   50  67  98   97  54
# 44  張軒宸   58  86  71   65  85
# 45  黃淑芬   83  70  91   56  58
# 46  邱亭君   98  94  62   91  98
# 47  楊綺芬   59  55  64   78  99
# 48  馮淑芬   68  90  53   68  93
# 49  蕭怡伶  100  54  56   98  87
# 50  林柏洋   71  51  83   74  92
